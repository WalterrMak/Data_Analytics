# %%
import pandas as pd
#settings :
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', 1000)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
data = pd.read_csv('arreste_clean_data.csv')
data.sample(10)

#here we can see the data
# Out:
#        DATA_YEAR  AGENCY_ID RESIDENT_CODE  ARRESTEE_ID  ARRESTEE_SEQ_NUM ARREST_DATE    ARREST_TYPE_NAME MULTIPLE_INDICATOR  INCIDENT_ID INCIDENT_DATE  INCIDENT_HOUR   OFFENSE_CATEGORY_NAME              OFFENSE_NAME CRIME_AGAINST  AGE_NUM SEX_CODE  RACE_ID RACE_CODE                  RACE_DESC
# 1203        2020      13282           NaN     41267677                 1   06-NOV-20  Taken INTO Custody                  C    133630721     08-SEP-20             20  Drug/Narcotic Offenses  Drug/Narcotic Violations       Society       42        M        1         W                      White
# 5335        2020      13001             R     41285351                 1   21-NOV-20             On View                  N    133666959     21-NOV-20              5        Assault Offenses            Simple Assault        Person       40        M        1         W                      White
# ...

# %%
data.info()
#here we can see deeper info of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11624 entries, 0 to 11623
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATA_YEAR              11624 non-null  int64
#  1   AGENCY_ID              11624 non-null  int64
#  2   RESIDENT_CODE          6024 non-null   object
#  3   ARRESTEE_ID            11624 non-null  int64
#  4   ARRESTEE_SEQ_NUM       11624 non-null  int64
#  5   ARREST_DATE            11624 non-null  object
#  6   ARREST_TYPE_NAME       11624 non-null  object
#  7   MULTIPLE_INDICATOR     11624 non-null  object
#  8   INCIDENT_ID            11624 non-null  int64
#  9   INCIDENT_DATE          11624 non-null  object
#  10  INCIDENT_HOUR          11624 non-null  int64
#  11  OFFENSE_CATEGORY_NAME  11624 non-null  object
#  12  OFFENSE_NAME           11624 non-null  object
#  13  CRIME_AGAINST          11624 non-null  object
# ...

# %%
msno.bar(data) 
#just a different way to introduce the data / read it.
# Out:
# <AxesSubplot:>

# %%
data['DATA_YEAR'].unique()
#specify what exact data we want take we include unique.
# Out:
# array([2020])

# %%
len(data)
#the data from that year
# Out:
# 11624

# %%
data['DATA_YEAR'].value_counts()
#same thing in a different form
# Out:
# 2020    11624
# Name: DATA_YEAR, dtype: int64

# %%
data['SEX_CODE'].value_counts()
#data of men and women
# Out:
# M    8225
# F    3399
# Name: SEX_CODE, dtype: int64

# %%
data['ARREST_DATE'].value_counts()
#arrest data we can see dates on the left side 
#and the records on the right side of how many arrests there were.
# Out:
# 28-AUG-20    70
# 24-NOV-20    70
# 19-NOV-20    67
# 01-OCT-20    65
# 21-OCT-20    63
# 20-OCT-20    61
# 27-OCT-20    57
# 24-SEP-20    56
# 25-FEB-20    56
# 28-OCT-20    56
# 13-NOV-20    55
# 13-AUG-20    55
# 09-NOV-20    55
# 13-OCT-20    55
# 12-OCT-20    54
# 04-NOV-20    54
# 07-OCT-20    53
# 18-AUG-20    53
# 20-NOV-20    53
# 18-SEP-20    52
# 17-JUL-20    52
# 25-AUG-20    52
# 10-SEP-20    52
# 04-DEC-20    52
# 31-AUG-20    51
# 09-SEP-20    51
# 30-OCT-20    51
# 03-DEC-20    51
# 22-DEC-20    51
# 30-JUL-20    51
# 15-SEP-20    51
# 21-NOV-20    50
# 14-OCT-20    50
# 03-SEP-20    50
# 30-AUG-20    50
# 26-AUG-20    49
# 30-SEP-20    49
# 29-SEP-20    49
# 20-AUG-20    48
# 22-OCT-20    48
# 22-SEP-20    48
# 15-DEC-20    48
# 25-SEP-20    48
# 20-DEC-20    47
# 21-SEP-20    47
# 09-OCT-20    47
# 12-NOV-20    47
# 05-OCT-20    46
# 11-DEC-20    46
# 29-OCT-20    46
# 23-OCT-20    46
# 01-DEC-20    46
# 15-OCT-20    45
# 06-AUG-20    45
# 08-OCT-20    45
# ...

# %%
data['INCIDENT_DATE'].value_counts()
#Same thing date and how many incidents on that date.
# Out:
# 01-OCT-20    59
# 08-NOV-20    58
# 27-OCT-20    55
# 18-AUG-20    55
# 30-AUG-20    53
# 17-OCT-20    53
# 19-NOV-20    52
# 10-NOV-20    52
# 11-OCT-20    52
# 21-NOV-20    51
# 02-FEB-20    50
# 16-SEP-20    50
# 05-JUL-20    50
# 03-SEP-20    50
# 09-SEP-20    50
# 21-OCT-20    49
# 09-NOV-20    49
# 22-AUG-20    49
# 11-AUG-20    48
# 10-SEP-20    48
# 25-OCT-20    48
# 03-OCT-20    48
# 17-JUL-20    48
# 20-NOV-20    48
# 12-OCT-20    47
# 07-OCT-20    47
# 28-AUG-20    47
# 06-AUG-20    47
# 13-AUG-20    46
# 10-OCT-20    45
# 09-OCT-20    45
# 22-MAY-20    45
# 24-SEP-20    45
# 29-OCT-20    45
# 24-NOV-20    45
# 13-OCT-20    45
# 12-JUL-20    44
# 25-SEP-20    44
# 20-OCT-20    44
# 22-OCT-20    44
# 04-DEC-20    44
# 19-SEP-20    44
# 03-DEC-20    43
# 18-SEP-20    43
# 14-OCT-20    43
# 18-JUL-20    42
# 20-AUG-20    42
# 11-DEC-20    42
# 08-OCT-20    42
# 01-NOV-20    42
# 06-NOV-20    42
# 18-OCT-20    42
# 19-DEC-20    42
# 14-MAR-20    41
# 08-SEP-20    41
# ...

# %%
data['OFFENSE_CATEGORY_NAME'].value_counts()
#Here we can see offences and how many offences were done.
# Out:
# Larceny/Theft Offenses                      3759
# Assault Offenses                            3048
# Drug/Narcotic Offenses                      1863
# Destruction/Damage/Vandalism of Property    1181
# Burglary/Breaking & Entering                 489
# Stolen Property Offenses                     247
# Weapon Law Violations                        218
# Motor Vehicle Theft                          182
# Robbery                                      181
# Sex Offenses                                 114
# Fraud Offenses                               111
# Kidnapping/Abduction                          79
# Counterfeiting/Forgery                        67
# Prostitution Offenses                         27
# Arson                                         24
# Homicide Offenses                             15
# Sex Offenses, Non-forcible                     7
# Pornography/Obscene Material                   7
# Embezzlement                                   3
# ...

# %%
data['RACE_CODE'].value_counts()
#Here we can see what race the person making the crime is.
# Out:
# W    7246
# B    4083
# A     125
# U     118
# I      49
# P       3
# Name: RACE_CODE, dtype: int64
